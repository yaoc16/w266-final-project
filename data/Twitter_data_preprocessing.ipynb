# %% [markdown]
# ## Mount Shared Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Twitter Data

# %%
# # Get Data
d = pd.read_csv('twitter.csv',encoding='latin-1',header = None)

data = d[[0,5]]
data.columns = ['rating_label','reviewText']
data.head()
# Out:
#    rating_label                                         reviewText
# 0             0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1             0  is upset that he can't update his Facebook by ...
# 2             0  @Kenichan I dived many times for the ball. Man...
# 3             0    my whole body feels itchy and like its on fire
# 4             0  @nationwideclass no, it's not behaving at all....

# %%
data.rating_label.value_counts()
# Out:
# 0    800000
# 1    800000
# Name: rating_label, dtype: int64

# %%
# label mapping
data['rating_label'] = data['rating_label'].map({0:0, 4:1})
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.to_csv('twitter_processed.csv',index=False)
